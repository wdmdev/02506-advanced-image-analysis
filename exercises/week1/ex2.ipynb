# %% [markdown]
# # Length of Segmentation Boundary

# %%
import os
import cv2
import sys
import matplotlib.pyplot as plt

sys.path.append(os.path.join(os.path.abspath(''), '..', '..'))
from toolbox import segmentation
import imp
imp.reload(segmentation)
# Out:
# <module 'toolbox.segmentation' from '/Users/williammarstrand/privat/DTU/Kandidat/1. Semester/Advanced Image Analysis/02506-advanced-image-analysis/exercises/week1/../../toolbox/segmentation.py'>

# %%
fuel_cell1 = cv2.imread(os.path.join('data' , 'fuel_cells', 'fuel_cell_1.tif'))
fuel_cell2 = cv2.imread(os.path.join('data' , 'fuel_cells', 'fuel_cell_2.tif'))
fuel_cell3 = cv2.imread(os.path.join('data' , 'fuel_cells', 'fuel_cell_3.tif'))

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,10))

ax[0].set_title('Fuel cell 1')
ax[0].imshow(fuel_cell1)
ax[1].set_title('Fuel cell 2')
ax[1].imshow(fuel_cell2)
ax[2].set_title('Fuel cell 3')
ax[2].imshow(fuel_cell3)
plt.show()

# %% [markdown]
# ## Task 1

# %% [markdown]
# *Compute the length of the segmentation boundary for provided
# segmentation images of a fuel cell, where one is shown in Figure 1.5.
# You can consider avoiding loops and instead using vectorization
# provided by Matlab or numpy, which will ensure an efficient and
# compact implementation.*

# %%
fuel_cell1_bound_len = segmentation.segmentation_boundary_length(fuel_cell1)
print(f'Boundary Length Fuel Cell 1: {fuel_cell1_bound_len}')
fuel_cell2_bound_len = segmentation.segmentation_boundary_length(fuel_cell2)
print(f'Boundary Length Fuel Cell 2: {fuel_cell2_bound_len}')
fuel_cell3_bound_len = segmentation.segmentation_boundary_length(fuel_cell3)
print(f'Boundary Length Fuel Cell 3: {fuel_cell3_bound_len}')
# Out:
# Boundary Length Fuel Cell 1: 48984
# Boundary Length Fuel Cell 2: 32403
# Boundary Length Fuel Cell 3: 24252
